# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import random

DATADIR = '/Users/erdemgumusoglu/Desktop/Erdem/Uni/WING/5Sem/IT_Projekt2'
CATEGORIES = ["Biomüll","Restmuell"]
                       
for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    print(path)
    for img in os.listdir(path):
        if img != ".DS_Store":
            print(img)
            print(path)
            img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_UNCHANGED)
            print(img_array)
            plt.imshow(img_array)
            plt.show()
        else:
            continue
# Out:
# /Users/erdemgumusoglu/Desktop/Erdem/Uni/WING/5Sem/IT_Projekt2/Biomüll
# 0.jpg
# /Users/erdemgumusoglu/Desktop/Erdem/Uni/WING/5Sem/IT_Projekt2/Biomüll
# [[[13 25 13]
#   [14 26 14]
#   [12 25 11]
#   ...
#   [ 5 40  6]
#   [14 47 13]
#   [ 5 37  6]]
#
#  [[ 9 24 10]
#   [ 9 24 10]
#   [16 29 15]
#   ...
#   [ 6 39  4]
#   [15 48 13]
#   [ 7 40  6]]
#
#  [[ 7 23  6]
#   [11 27 10]
#   [14 29 15]
#   ...
#   [ 7 40  5]
#   [16 49 14]
#   [ 9 42  8]]
#
#  ...
#
#  [[27 28 38]
#   [30 29 39]
#   [30 29 39]
#   ...
#   [46 50 39]
#   [60 68 58]
#   [74 82 75]]
#
#  [[31 32 42]
#   [29 30 40]
#   [27 28 38]
#   ...
#   [45 50 41]
#   [39 44 35]
#   [33 37 31]]
#
#  [[29 28 38]
#   [32 31 41]
#   [29 30 40]
#   ...
#   [35 39 33]
#   [40 42 36]
#   [38 40 34]]]
# 1.jpg
# /Users/erdemgumusoglu/Desktop/Erdem/Uni/WING/5Sem/IT_Projekt2/Biomüll
# [[[105  96 123]
#   [104  98 123]
#   [102  98 123]
#   ...
#   [103 103 115]
#   [103 101 120]
#   [102  98 123]]
#
#  [[104 101 126]
# ...

# %%
print(img_array.shape)
a = img_array.shape[0]
b = img_array.shape[1]
# Out:
# (420, 512, 3)

# %%
training_data = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            if img != ".DS_Store":
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_UNCHANGED)
                plt.imshow(img_array)
                plt.show()
                training_data.append([img_array, class_num])
            else:
                continue

create_training_data()

# %%
print(len(training_data))
# Out:
# 10

# %%
random.shuffle(training_data)

# %%
for sample in training_data[:3]:
    print(sample[1])
# Out:
# 1
# 1
# 0

# %%
X = []
Y = []

for features, label in training_data:
    X.append(features)
    Y.append(label)

X = np.array(X).reshape(-1, a, b, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-3f6c959a6c3d> in <module>
#       6     Y.append(label)
#       7
# ----> 8 X = np.array(X).reshape(-1, a, b, 1)
#
# ValueError: cannot reshape array of size 10 into shape (420,512,1)

# %%
import pickle

pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle",'rb')
X = pickle.load(pickle_in)
print(X)
# Out:
# [array([[[ 43,  52,  85],
#         [ 16,  25,  58],
#         [ 43,  52,  85],
#         ...,
#         [ 60,  58,  88],
#         [ 50,  48,  78],
#         [ 41,  39,  69]],
#
#        [[ 22,  31,  64],
#         [ 12,  21,  54],
#         [ 50,  59,  92],
#         ...,
#         [117, 115, 144],
#         [110, 108, 138],
#         [105, 103, 132]],
#
#        [[ 28,  37,  70],
#         [ 19,  28,  61],
#         [ 55,  64,  97],
#         ...,
#         [118, 117, 143],
#         [117, 115, 144],
#         [116, 115, 141]],
#
#        ...,
#
#        [[ 61,  60,  70],
#         [ 45,  44,  54],
#         [ 25,  24,  34],
#         ...,
#         [ 50,  52,  70],
#         [ 56,  58,  76],
#         [ 60,  62,  80]],
#
#        [[ 57,  56,  66],
#         [ 31,  30,  40],
#         [ 13,  12,  22],
#         ...,
#         [ 74,  76,  94],
#         [ 72,  74,  92],
#         [ 60,  62,  80]],
#
#        [[ 58,  57,  67],
#         [ 21,  20,  30],
#         [  8,   7,  17],
# ...

# %%
X[0]
# Out:
# array([[[ 43,  52,  85],
#         [ 16,  25,  58],
#         [ 43,  52,  85],
#         ...,
#         [ 60,  58,  88],
#         [ 50,  48,  78],
#         [ 41,  39,  69]],
#
#        [[ 22,  31,  64],
#         [ 12,  21,  54],
#         [ 50,  59,  92],
#         ...,
#         [117, 115, 144],
#         [110, 108, 138],
#         [105, 103, 132]],
#
#        [[ 28,  37,  70],
#         [ 19,  28,  61],
#         [ 55,  64,  97],
#         ...,
#         [118, 117, 143],
#         [117, 115, 144],
#         [116, 115, 141]],
#
#        ...,
#
#        [[ 61,  60,  70],
#         [ 45,  44,  54],
#         [ 25,  24,  34],
#         ...,
#         [ 50,  52,  70],
#         [ 56,  58,  76],
#         [ 60,  62,  80]],
#
#        [[ 57,  56,  66],
#         [ 31,  30,  40],
#         [ 13,  12,  22],
#         ...,
#         [ 74,  76,  94],
#         [ 72,  74,  92],
#         [ 60,  62,  80]],
#
#        [[ 58,  57,  67],
#         [ 21,  20,  30],
#         [  8,   7,  17],
# ...

# %%
import gitlab
import json

curl "'https://gitlab.lrz.de/hm-guemueso/awm.ideas.git'"
gl = gitlab.Gitlab('https://gitlab.lrz.de/hm-guemueso/awm.ideas.git')
#gl.auth()
print(gl)
#project = gl.projects.get('https://gitlab.lrz.de/hm-guemueso/awm.ideas.git')
#project = gl.projects.get('hm-guemueso/awm.ideas')
#items = project.repository_tree('/tree/master/Biomüll')
#for i in items:
#    print(i)

# %%
curl "https://gitlab.lrz.de/api/v4/projects/67809"
# Out:
#   File "<ipython-input-27-0bbecbca0a6f>", line 1
#     curl "https://gitlab.lrz.de/api/v4/projects/67809"
#                                                      ^
# SyntaxError: invalid syntax

# %%
import git

git.Git ("https://github.com/guemueso/AWM.git").clone("https://gitlab.lrz.de/hm-guemueso/awm.ideas.git")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/git/cmd.py in execute(self, command, istream, with_extended_output, with_exceptions, as_process, output_stream, stdout_as_string, kill_after_timeout, with_stdout, universal_newlines, shell, env, max_chunk_size, **subprocess_kwargs)
#     731                          creationflags=PROC_CREATIONFLAGS,
# --> 732                          **subprocess_kwargs
#     733                          )
#
# ~/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
# ...

# %%
from git import Repo

Repo.clone_from("https://gitlab.lrz.de/hm-guemueso/awm.ideas.git", '/Users/erdemgumusoglu/Downloads')
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# <ipython-input-36-826c076f8b3b> in <module>
#       1 from git import Repo
#       2
# ----> 3 Repo.clone_from("https://gitlab.lrz.de/hm-guemueso/awm.ideas.git", '/Users/erdemgumusoglu/Downloads')
#       4
#
# ~/anaconda3/lib/python3.7/site-packages/git/repo/base.py in clone_from(cls, url, to_path, progress, env, multi_options, **kwargs)
#    1030         if env is not None:
#    1031             git.update_environment(**env)
# -> 1032         return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#    1033
#    1034     def archive(self, ostream, treeish=None, prefix=None, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/git/repo/base.py in _clone(cls, git, url, path, odb_default_type, progress, multi_options, **kwargs)
#     971             (stdout, stderr) = proc.communicate()
# ...

# %%
#'https://github.com/guemueso/AWM/issues/3#issue-752315737'
    
cv2.imread('https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/blob/master/Biomüll/0.jpg', cv2.IMREAD_UNCHANGED)
print(img_array)
# Out:
# [[[157 182 138]
#   [157 182 138]
#   [161 186 142]
#   ...
#   [171 191 148]
#   [174 194 151]
#   [174 194 151]]
#
#  [[161 186 142]
#   [161 186 142]
#   [164 189 145]
#   ...
#   [171 191 148]
#   [171 191 148]
#   [169 189 146]]
#
#  [[154 179 135]
#   [154 179 135]
#   [157 182 138]
#   ...
#   [169 190 145]
#   [168 188 145]
#   [166 186 143]]
#
#  ...
#
#  [[110 136  96]
#   [116 142 102]
#   [120 145 107]
#   ...
#   [152 172 130]
#   [152 172 129]
#   [149 169 126]]
#
#  [[108 134  94]
#   [113 139  99]
#   [116 141 103]
#   ...
#   [152 172 130]
#   [152 172 129]
#   [149 169 126]]
#
#  [[108 134  94]
#   [112 138  98]
#   [114 139 101]
#   ...
#   [152 172 130]
#   [151 171 128]
#   [149 169 126]]]

# %%
name = 'https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/'

number = (1,2,3,4,5,6,7,8,9,0)
for i in range(0,9):
    print(name+str(i)+'.jpg')


#https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/blob/master/Biomüll/0.jpg
#https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/blob/master/Biomüll/1.jpg
# Out:
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/0.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/1.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/2.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/3.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/4.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/5.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/6.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/7.jpg
# -1
# https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll/8.jpg

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

url = input("name: ")
if type(url) == str:
    # Ignore errors even if the string is not proper UTF-8 or has
    # broken marker bytes.
    # Python built-in function unicode() can do this.
    url = unicode(url, "utf-8", errors="ignore")
else:
    # Assume the value object has proper __unicode__() method
    url = unicode(url)
uh = urllib.request.urlopen(url)
data = uh.read().decode()

info = json.loads(data)

count = 0
sum = 0
enter = info["comments"]
for i in enter:
    enter = info["comments"][count]["count"]
    sum += int(enter)
    count +=1
print(sum)
# Out:
# name: https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-37b3d696276b> in <module>
#       8     # broken marker bytes.
#       9     # Python built-in function unicode() can do this.
# ---> 10     url = unicode(url, "utf-8", errors="ignore")
#      11 else:
#      12     # Assume the value object has proper __unicode__() method
#
# NameError: name 'unicode' is not defined

# %%
import urllib.request,  urllib.parse, urllib.error
from bs4 import BeautifulSoup

url = input("Enter:")
url.encode('ascii', 'ignore')
html = urllib.request.urlopen(url).read()
url.encode('ascii', 'ignore')
soup = BeautifulSoup(html, "html.parser")

total = 0
tags = soup("span")
for tag in tags:
    #print(tag.get(">.",tag ))
    #print('TAG:', tag)
    #print('URL:', tag.get('href', None))
    #print('Contents:', tag.contents[0])
    #print('Attrs:', tag.attrs)
    numbers = int(tag.contents[0])
    total += numbers
print(total)
# Out:
# Enter:https://gitlab.lrz.de/hm-guemueso/awm.ideas/-/tree/master/Biomüll
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-50-2f3912f4dfe0> in <module>
#       4 url = input("Enter:")
#       5 url.encode('ascii', 'ignore')
# ----> 6 html = urllib.request.urlopen(url).read()
#       7 url.encode('ascii', 'ignore')
#       8 soup = BeautifulSoup(html, "html.parser")
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
# ...
